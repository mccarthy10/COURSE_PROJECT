# %% [markdown]
# MCCARTHY RAPHAEL ANSAH
# 11116438
# MTEN

# %%
import pandas as pd

# %%
import matplotlib as md

# %%
import numpy as np

# %%
 dataset=pd.read_csv("red_wine.csv")

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
dataset.shape
# Out:
# (1599, 12)

# %%
dataset.size
# Out:
# 19188

# %%
dataset.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255282     0.671371
# volatile acidity          -0.255282          1.000000    -0.552334
# citric acid                0.671371         -0.552334     1.000000
# residual sugar             0.114743          0.002075     0.143577
# chlorides                  0.093866          0.061107     0.203944
# free sulfur dioxide       -0.153762         -0.010496    -0.061884
# total sulfur dioxide      -0.112632          0.076881     0.035533
# density                    0.667799          0.021796     0.365370
# pH                        -0.683021          0.234801    -0.541904
# sulphates                  0.183213         -0.260870     0.312770
# alcohol                   -0.061062         -0.202097     0.109903
# quality                    0.124639         -0.390721     0.226166
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.figure("1599,12")

# %%
plt.plot(dataset)

# %%
#Scatter diagram of residual sugar and fixed sugar

# %%
plt.scatter(dataset['residual sugar'],dataset['fixed acidity'])
plt.xlabel('residual sugar')
plt.ylabel('fixed acidity')
plt.title ('Relationship between residual sugar and fixed acidity')
plt.show()

# %%
#Barchart of volatile acidity and equality

# %%
x = (dataset['quality'])
y=(dataset['volatile acidity'])
plt.xlabel ('quality')
plt.ylabel('volatile acidity')
plt.bar(x,y)
plt.title('Relationship between volatile acidity and quality')
plt.show()

# %% [markdown]
# # BAR GRAPH DISTRIBUTION OF VOLATILE ACIDITY

# %% [markdown]
# ## Introduction

# %% [markdown]
# This report shows the relationship between the volatile acidity and the quality through a bar chart.The volatile acidity is measured on the vertical-y-axis and the quality on the horizontal-x-axis.The volatile acidity starts reading from 0.0 through to 1.6 while the quality reads from 0 through to 8.

# %% [markdown]
# ## Body

# %% [markdown]
# From the graph,it is shown that the quality of the red wine does not depend on the volatile acidity.Thus the relationship between the quality of the wine and the volatile acidity is not directly proportional.This is because the highest level of volatile acidity measured is correspondent to the lowest level of the quality of the red wine . Therefore,it's observed that there's no pattern or logic with the plotting since not all the values obey the same logic.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# To conclude,the bar chart virtualizes the quality of the red wine and the volatile acidity of the wine.The volatile acidity does not necessarily affect the quality of the red wine.
